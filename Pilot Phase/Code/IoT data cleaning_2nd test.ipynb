# %%
import urllib.request, json
import requests
import numpy as np
import pandas as pd
from itertools import chain
def datacleaning(bcurl,GPSurl):
    r = requests.get(bcurl)
    dictr = r.json()
    main = pd.DataFrame.from_dict(dictr)
    beacons = main["beacons"]
    beacondetails = pd.DataFrame(list(chain.from_iterable(beacons)))
    beacondata = beacondetails["ibeacon_data"]
    beacondatadf = pd.DataFrame(beacondata)
    beacondatadetails = beacondatadf["ibeacon_data"].apply(pd.Series)
    detailsdf = pd.concat([main, beacondetails, beacondatadetails],axis=1)
    cleandf = detailsdf[['timestamp','name','beacon_type','distance','hashcode','isBlocked','last_seen','manufacturer','rssi','tx_power','eddystoneUidData','major','minor','uuid']]
    finaldf = cleandf[cleandf["timestamp"].notnull()]
    GPS=pd.read_csv(GPSurl,sep=',')
    finaldf['timestamp']=pd.to_datetime(finaldf['timestamp'])
    GPS['date time']=pd.to_datetime(GPS['date time'])
    df=finaldf.merge(GPS, left_on='timestamp', right_on='date time')
    return df

# %%
df1=datacleaning('http://143.198.161.82:56789/get/device1','/Users/anboguo/Desktop/device1 - 20210924-151809.txt')
df1
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 timestamp   name_x beacon_type  distance    hashcode  \
# 0     2021-09-24 19:18:47  device1     ibeacon  4.600171 -1229677222
# 1     2021-09-24 19:18:48  device1     ibeacon  6.358023    32202963
# 2     2021-09-24 19:19:16  device1     ibeacon  4.040893   144680941
# 3     2021-09-24 19:19:23  device1     ibeacon  8.462784   144680941
# 4     2021-09-24 19:19:25  device1     ibeacon  7.056213   144680941
# ...                   ...      ...         ...       ...         ...
# 25489 2021-09-24 21:58:15  device1     ibeacon  3.233470  -245613548
# ...

# %%
df3=datacleaning('http://143.198.161.82:56789/get/device3','/Users/anboguo/Desktop/device3 - 20210924-211003.txt')
df3
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                timestamp   name_x beacon_type   distance   hashcode  \
# 0    2021-09-24 23:29:05  device3     ibeacon   8.200326 -771085463
# 1    2021-09-24 23:29:05  device3     ibeacon   8.200326 -771085463
# 2    2021-09-24 23:29:05  device3     ibeacon   8.200326 -771085463
# 3    2021-09-24 23:29:05  device3     ibeacon   8.350944 -771085463
# 4    2021-09-24 23:29:05  device3     ibeacon   8.131318 -771085463
# ...                  ...      ...         ...        ...        ...
# 8973 2021-10-03 00:20:47  device3     ibeacon  15.664127  992089174
# 8974 2021-10-03 00:20:47  device3     ibeacon  15.394053  992089174
# ...

# %%
df4=datacleaning('http://143.198.161.82:56789/get/device4','/Users/anboguo/Desktop/device4 - 20210928-154234.txt')
df4
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               timestamp   name_x    beacon_type   distance    hashcode  \
# 0   2021-09-28 19:42:44  device4  eddystone_uid   5.683823   -52086734
# 1   2021-09-28 19:42:44  device4        ibeacon  14.787390   -47281815
# 2   2021-09-28 19:42:44  device4  eddystone_uid   4.561479    90464375
# 3   2021-09-28 19:42:53  device4        ibeacon   3.349874   145574607
# 4   2021-09-28 19:42:54  device4        ibeacon   2.645353   147513809
# ..                  ...      ...            ...        ...         ...
# 214 2021-09-28 20:37:49  device4        ibeacon   2.962613  -245613548
# ...
